# %% [markdown]
# # XLS and XLSX files. . Exercise 4
#
# Pandas documentation: https://pandas.pydata.org/docs/index.html
#
# Pandas API reference: https://pandas.pydata.org/docs/reference/index.html#api

# %%
# import pandas library
import pandas as pd

# %% [markdown]
# ### Sales Dataset
#
# **Source**: Tableau Community
#
# https://community.tableau.com/s/question/0D54T00000CWeX8SAL/sample-superstore-sales-excelxls

# %%
# Load the Excel file from GitHub repo
file = 'https://github.com/bigdatawirtz/sistemas-bigdata-2024/raw/refs/heads/main/datasets/sample_superstore.xls'
df_store = pd.read_excel(file)

# %%
# Load XLS file (from local filesystem)
df_store = pd.read_excel('../../data/Sample_Superstore.xls')

# %%
# show DataFrame
df_store
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 1          2  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 2          3  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 3          4  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 4          5  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    9990  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 9990    9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9991    9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9992    9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9993    9994  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# 0       CG-12520       Claire Gute   Consumer  United States        Henderson
# 1       CG-12520       Claire Gute   Consumer  United States        Henderson
# 2       DV-13045   Darrin Van Huff  Corporate  United States      Los Angeles
# 3       SO-20335    Sean O'Donnell   Consumer  United States  Fort Lauderdale
# 4       SO-20335    Sean O'Donnell   Consumer  United States  Fort Lauderdale
# ...          ...               ...        ...            ...              ...
# 9989    TB-21400  Tom Boeckenhauer   Consumer  United States            Miami
# 9990    DB-13060       Dave Brooks   Consumer  United States       Costa Mesa
# 9991    DB-13060       Dave Brooks   Consumer  United States       Costa Mesa
# 9992    DB-13060       Dave Brooks   Consumer  United States       Costa Mesa
# 9993    CC-12220      Chris Cortes   Consumer  United States      Westminster
#
#       ... Postal Code  Region       Product ID         Category Sub-Category  \
# 0     ...       42420   South  FUR-BO-10001798        Furniture    Bookcases
# 1     ...       42420   South  FUR-CH-10000454        Furniture       Chairs
# 2     ...       90036    West  OFF-LA-10000240  Office Supplies       Labels
# 3     ...       33311   South  FUR-TA-10000577        Furniture       Tables
# 4     ...       33311   South  OFF-ST-10000760  Office Supplies      Storage
# ...   ...         ...     ...              ...              ...          ...
# 9989  ...       33180   South  FUR-FU-10001889        Furniture  Furnishings
# 9990  ...       92627    West  FUR-FU-10000747        Furniture  Furnishings
# 9991  ...       92627    West  TEC-PH-10003645       Technology       Phones
# 9992  ...       92627    West  OFF-PA-10004041  Office Supplies        Paper
# 9993  ...       92683    West  OFF-AP-10002684  Office Supplies   Appliances
#
#                                            Product Name     Sales  Quantity  \
# 0                     Bush Somerset Collection Bookcase  261.9600         2
# 1     Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400         3
# 2     Self-Adhesive Address Labels for Typewriters b...   14.6200         2
# 3         Bretford CR4500 Series Slim Rectangular Table  957.5775         5
# 4                        Eldon Fold 'N Roll Cart System   22.3680         2
# ...                                                 ...       ...       ...
# 9989                             Ultra Door Pull Handle   25.2480         3
# 9990  Tenex B1-RE Series Chair Mats for Low Pile Car...   91.9600         2
# 9991                              Aastra 57i VoIP phone  258.5760         2
# 9992  It's Hot Message Books with Stickers, 2 3/4" x 5"   29.6000         4
# 9993  Acco 7-Outlet Masterpiece Power Center, Wihtou...  243.1600         2
#
#       Discount    Profit
# 0         0.00   41.9136
# 1         0.00  219.5820
# 2         0.00    6.8714
# 3         0.45 -383.0310
# 4         0.20    2.5164
# ...        ...       ...
# 9989      0.20    4.1028
# 9990      0.00   15.6332
# 9991      0.20   19.3932
# 9992      0.00   13.3200
# 9993      0.00   72.9480
#
# [9994 rows x 21 columns]

# %%
# Show the 3 first rows
df_store.loc[0:2]
# Out:
#    Row ID        Order ID Order Date  Ship Date     Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11  Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11  Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16  Second Class    DV-13045
#
#      Customer Name    Segment        Country         City  ... Postal Code  \
# 0      Claire Gute   Consumer  United States    Henderson  ...       42420
# 1      Claire Gute   Consumer  United States    Henderson  ...       42420
# 2  Darrin Van Huff  Corporate  United States  Los Angeles  ...       90036
#
#    Region       Product ID         Category Sub-Category  \
# 0   South  FUR-BO-10001798        Furniture    Bookcases
# 1   South  FUR-CH-10000454        Furniture       Chairs
# 2    West  OFF-LA-10000240  Office Supplies       Labels
#
#                                         Product Name   Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.96         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.94         3
# 2  Self-Adhesive Address Labels for Typewriters b...   14.62         2
#
#    Discount    Profit
# 0       0.0   41.9136
# 1       0.0  219.5820
# 2       0.0    6.8714
#
# [3 rows x 21 columns]

# %%
# Show 5 random rows
df_store.sample(5)
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 4974    4975  CA-2016-164896 2016-11-07 2016-11-12  Standard Class
# 6812    6813  CA-2017-156237 2017-09-14 2017-09-15     First Class
# 1390    1391  US-2016-108504 2016-02-05 2016-02-05        Same Day
# 1418    1419  CA-2015-126697 2015-09-21 2015-09-24     First Class
# 4023    4024  CA-2017-130764 2017-10-27 2017-10-28     First Class
#
#      Customer ID    Customer Name      Segment        Country           City  \
# 4974    PS-19045  Penelope Sewall  Home Office  United States      Oceanside
# 6812    PS-18760     Pamela Stobb     Consumer  United States   Philadelphia
# 1390    PP-18955       Paul Prost  Home Office  United States         Smyrna
# 1418    SV-20815       Stuart Van    Corporate  United States        Houston
# 4023    JO-15145    Jack O'Briant    Corporate  United States  San Francisco
#
#       ... Postal Code   Region       Product ID         Category Sub-Category  \
# 4974  ...       92054     West  OFF-PA-10002246  Office Supplies        Paper
# 6812  ...       19140     East  OFF-BI-10003707  Office Supplies      Binders
# 1390  ...       30080    South  OFF-PA-10000357  Office Supplies        Paper
# 1418  ...       77041  Central  FUR-FU-10001706        Furniture  Furnishings
# 4023  ...       94110     West  FUR-BO-10003034        Furniture    Bookcases
#
#                                            Product Name    Sales  Quantity  \
# 4974  Wirebound Four 2-3/4 x 5 Forms per Page, 400 S...   12.900         2
# 6812                               Aluminum Screw Posts   18.312         4
# 1390  White Dual Perf Computer Printout Paper, 2700 ...  122.970         3
# 1418                       Longer-Life Soft White Bulbs    4.928         4
# 4023      O'Sullivan Elevations Bookcase, Cherry Finish  556.665         5
#
#       Discount   Profit
# 4974      0.00   6.3210
# 6812      0.70 -12.2080
# 1390      0.00  60.2553
# 1418      0.60  -1.4784
# 4023      0.15   6.5490
#
# [5 rows x 21 columns]

# %%
# From the last 10 rows, show the 5 first ones
df_store.tail(10).head(5)
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 9984    9985  CA-2015-100251 2015-05-17 2015-05-23  Standard Class
# 9985    9986  CA-2015-100251 2015-05-17 2015-05-23  Standard Class
# 9986    9987  CA-2016-125794 2016-09-29 2016-10-03  Standard Class
# 9987    9988  CA-2017-163629 2017-11-17 2017-11-21  Standard Class
# 9988    9989  CA-2017-163629 2017-11-17 2017-11-21  Standard Class
#
#      Customer ID     Customer Name    Segment        Country         City  \
# 9984    DV-13465  Dianna Vittorini   Consumer  United States   Long Beach
# 9985    DV-13465  Dianna Vittorini   Consumer  United States   Long Beach
# 9986    ML-17410      Maris LaWare   Consumer  United States  Los Angeles
# 9987    RA-19885      Ruben Ausman  Corporate  United States       Athens
# 9988    RA-19885      Ruben Ausman  Corporate  United States       Athens
#
#       ... Postal Code  Region       Product ID         Category Sub-Category  \
# 9984  ...       11561    East  OFF-LA-10003766  Office Supplies       Labels
# 9985  ...       11561    East  OFF-SU-10000898  Office Supplies     Supplies
# 9986  ...       90008    West  TEC-AC-10003399       Technology  Accessories
# 9987  ...       30605   South  TEC-AC-10001539       Technology  Accessories
# 9988  ...       30605   South  TEC-PH-10004006       Technology       Phones
#
#                                            Product Name   Sales  Quantity  \
# 9984                     Self-Adhesive Removable Labels   31.50        10
# 9985  Acme Hot Forged Carbon Steel Scissors with Nic...   55.60         4
# 9986  Memorex Mini Travel Drive 64 GB USB 2.0 Flash ...   36.24         1
# 9987  Logitech G430 Surround Sound Gaming Headset wi...   79.99         1
# 9988                    Panasonic KX - TS880B Telephone  206.10         5
#
#       Discount   Profit
# 9984       0.0  15.1200
# 9985       0.0  16.1240
# 9986       0.0  15.2208
# 9987       0.0  28.7964
# 9988       0.0  55.6470
#
# [5 rows x 21 columns]

# %%
# Show 3 random rows from the first 50 ones
df_store.head(50).sample( 3, random_state = 42)
# Out:
#     Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 13      14  CA-2016-161389 2016-12-05 2016-12-10  Standard Class    IM-15070
# 39      40  CA-2015-117415 2015-12-27 2015-12-31  Standard Class    SN-20710
# 30      31  US-2015-150630 2015-09-17 2015-09-21  Standard Class    TB-21520
#
#       Customer Name      Segment        Country          City  ...  \
# 13     Irene Maddox     Consumer  United States       Seattle  ...
# 39     Steve Nguyen  Home Office  United States       Houston  ...
# 30  Tracy Blumstein     Consumer  United States  Philadelphia  ...
#
#    Postal Code   Region       Product ID         Category Sub-Category  \
# 13       98103     West  OFF-BI-10003656  Office Supplies      Binders
# 39       77041  Central  FUR-CH-10004218        Furniture       Chairs
# 30       19140     East  OFF-EN-10001509  Office Supplies    Envelopes
#
#                                    Product Name    Sales  Quantity  Discount  \
# 13  Fellowes PB200 Plastic Comb Binding Machine  407.976         3       0.2
# 39     Global Fabric Manager's Chair, Dark Gray  212.058         3       0.3
# 30                    Poly String Tie Envelopes    3.264         2       0.2
#
#       Profit
# 13  132.5922
# 39  -15.1470
# 30    1.1016
#
# [3 rows x 21 columns]

# %%
# Show info about column data types
df_store.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   datetime64[ns]
#  3   Ship Date      9994 non-null   datetime64[ns]
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
#  17  Sales          9994 non-null   float64
#  18  Quantity       9994 non-null   int64
#  19  Discount       9994 non-null   float64
#  20  Profit         9994 non-null   float64
# dtypes: datetime64[ns](2), float64(3), int64(3), object(13)
# memory usage: 1.6+ MB

# %%
# Show the next info
#
# zip code type: 
#
# Discount type: 
#
# Country data type: 
# Display the data types of specific columns
df_store[['Postal Code', 'Discount', 'Country']].dtypes
# Out:
# Postal Code      int64
# Discount       float64
# Country         object
# dtype: object

# %%
# Show column names
df_store.columns.tolist()
# Out:
# ['Row ID',
#  'Order ID',
#  'Order Date',
#  'Ship Date',
#  'Ship Mode',
#  'Customer ID',
#  'Customer Name',
#  'Segment',
#  'Country',
#  'City',
#  'State',
#  'Postal Code',
#  'Region',
#  'Product ID',
#  'Category',
#  'Sub-Category',
#  'Product Name',
#  'Sales',
#  'Quantity',
#  'Discount',
#  'Profit']

# %%
# Select and show 5 different random cities
df_store.sample(5)
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 892      893  CA-2017-133256 2017-06-26 2017-06-27     First Class
# 2405    2406  CA-2017-108574 2017-10-07 2017-10-11  Standard Class
# 3604    3605  CA-2017-112956 2017-08-21 2017-08-27  Standard Class
# 9354    9355  CA-2015-110324 2015-12-01 2015-12-05  Standard Class
# 8904    8905  US-2016-126431 2016-07-01 2016-07-01        Same Day
#
#      Customer ID       Customer Name      Segment        Country  \
# 892     TH-21550       Tracy Hopkins  Home Office  United States
# 2405    MG-18145     Mike Gockenbach     Consumer  United States
# 3604    TH-21550       Tracy Hopkins  Home Office  United States
# 9354    MA-17560        Matt Abelman  Home Office  United States
# 8904    SU-20665  Stephanie Ulpright  Home Office  United States
#
#                City  ... Postal Code   Region       Product ID  \
# 892         Detroit  ...       48227  Central  OFF-AR-10003158
# 2405    Los Angeles  ...       90045     West  TEC-PH-10003555
# 3604       Columbia  ...       21044     East  FUR-FU-10003976
# 9354        Jackson  ...       49201  Central  OFF-PA-10001826
# 8904  New York City  ...       10009     East  OFF-LA-10001474
#
#              Category Sub-Category  \
# 892   Office Supplies          Art
# 2405       Technology       Phones
# 3604        Furniture  Furnishings
# 9354  Office Supplies        Paper
# 8904  Office Supplies       Labels
#
#                                            Product Name    Sales  Quantity  \
# 892                   Fluorescent Highlighters by Dixon   15.920         4
# 2405         Motorola HK250 Universal Bluetooth Headset  128.744         7
# 3604  DAX Executive Solid Wood Document Frame, Deskt...   25.160         2
# 9354                                          Xerox 207   19.440         3
# 8904                                          Avery 477   30.530         1
#
#       Discount   Profit
# 892        0.0   5.4128
# 2405       0.2 -28.9674
# 3604       0.0   8.5544
# 9354       0.0   9.3312
# 8904       0.0  14.0438
#
# [5 rows x 21 columns]

# %%
# Show the different countries that appear in the data
df_store['Country'].unique().tolist()
# Out:
# ['United States']

# %%
# Show the different categories
df_store['Category'].unique().tolist()
# Out:
# ['Furniture', 'Office Supplies', 'Technology']

# %%
# Select client id, name and city
df_store[['Customer ID','Customer Name', 'City']]
# Out:
#      Customer ID     Customer Name             City
# 0       CG-12520       Claire Gute        Henderson
# 1       CG-12520       Claire Gute        Henderson
# 2       DV-13045   Darrin Van Huff      Los Angeles
# 3       SO-20335    Sean O'Donnell  Fort Lauderdale
# 4       SO-20335    Sean O'Donnell  Fort Lauderdale
# ...          ...               ...              ...
# 9989    TB-21400  Tom Boeckenhauer            Miami
# 9990    DB-13060       Dave Brooks       Costa Mesa
# 9991    DB-13060       Dave Brooks       Costa Mesa
# 9992    DB-13060       Dave Brooks       Costa Mesa
# 9993    CC-12220      Chris Cortes      Westminster
#
# [9994 rows x 3 columns]

# %%
# Select Order ID (as Dataframe)
df_store[['Order ID']]
# Out:
#             Order ID
# 0     CA-2016-152156
# 1     CA-2016-152156
# 2     CA-2016-138688
# 3     US-2015-108966
# 4     US-2015-108966
# ...              ...
# 9989  CA-2014-110422
# 9990  CA-2017-121258
# 9991  CA-2017-121258
# 9992  CA-2017-121258
# 9993  CA-2017-119914
#
# [9994 rows x 1 columns]

# %%
# Count elements in Series "Region"
df_store['Region'].count()
# Out:
# np.int64(9994)

# %%
# Show elementes from "Region" Series
df_store['Region']
# Out:
# 0       South
# 1       South
# 2        West
# 3       South
# 4       South
#         ...
# 9989    South
# 9990     West
# 9991     West
# 9992     West
# 9993     West
# Name: Region, Length: 9994, dtype: object

# %%
# Count different elements in Series "Region"
df_store['Region'].nunique()
# Out:
# 4

# %%
# Create a Series with quantities in each order line and show the result
qs = df_store['Quantity']

# %%
# Show the lines with quantities greater than 2
qs[qs > 2]
# Out:
# 1        3
# 3        5
# 5        7
# 6        4
# 7        6
#         ..
# 9984    10
# 9985     4
# 9988     5
# 9989     3
# 9992     4
# Name: Quantity, Length: 6693, dtype: int64

# %%
# Show only the DataFrame lines with subcategory  "Tables"
df_store.query("`Sub-Category` == 'Tables'")
# df_store[df_store['Sub-Category'] == 'Tables'] #option 2
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 3          4  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 10        11  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# 24        25  CA-2015-106320 2015-09-25 2015-09-30  Standard Class
# 117      118  CA-2015-110457 2015-03-02 2015-03-06  Standard Class
# 125      126  US-2014-134614 2014-09-20 2014-09-25  Standard Class
# ...      ...             ...        ...        ...             ...
# 9857    9858  CA-2015-164301 2015-03-26 2015-03-30  Standard Class
# 9899    9900  US-2014-117380 2014-03-28 2014-04-03  Standard Class
# 9937    9938  CA-2016-164889 2016-06-03 2016-06-06    Second Class
# 9955    9956  CA-2015-141593 2015-12-14 2015-12-16    Second Class
# 9980    9981  US-2015-151435 2015-09-06 2015-09-09    Second Class
#
#      Customer ID    Customer Name      Segment        Country  \
# 3       SO-20335   Sean O'Donnell     Consumer  United States
# 10      BH-11710  Brosina Hoffman     Consumer  United States
# 24      EB-13870      Emily Burns     Consumer  United States
# 117     DK-13090        Dave Kipp     Consumer  United States
# 125     PF-19165       Philip Fox     Consumer  United States
# ...          ...              ...          ...            ...
# 9857    EB-13840    Ellis Ballard    Corporate  United States
# 9899    MP-18175   Mike Pelletier  Home Office  United States
# 9937    CP-12340   Christine Phan    Corporate  United States
# 9955    DB-12970      Darren Budd    Corporate  United States
# 9980    SW-20455      Shaun Weien     Consumer  United States
#
#                  City  ... Postal Code   Region       Product ID   Category  \
# 3     Fort Lauderdale  ...       33311    South  FUR-TA-10000577  Furniture
# 10        Los Angeles  ...       90032     West  FUR-TA-10001539  Furniture
# 24               Orem  ...       84057     West  FUR-TA-10000577  Furniture
# 117           Seattle  ...       98103     West  FUR-TA-10001768  Furniture
# 125       Bloomington  ...       61701  Central  FUR-TA-10004534  Furniture
# ...               ...  ...         ...      ...              ...        ...
# 9857          Seattle  ...       98103     West  FUR-TA-10001889  Furniture
# 9899      Springfield  ...       45503     East  FUR-TA-10000198  Furniture
# 9937      Los Angeles  ...       90049     West  FUR-TA-10001676  Furniture
# 9955      Los Angeles  ...       90045     West  FUR-TA-10002622  Furniture
# 9980        Lafayette  ...       70506    South  FUR-TA-10001039  Furniture
#
#      Sub-Category                                       Product Name  \
# 3          Tables      Bretford CR4500 Series Slim Rectangular Table
# 10         Tables           Chromcraft Rectangular Conference Tables
# 24         Tables      Bretford CR4500 Series Slim Rectangular Table
# 117        Tables                    Hon Racetrack Conference Tables
# 125        Tables                    Bevis 44 x 96 Conference Tables
# ...           ...                                                ...
# 9857       Tables  Bush Advantage Collection Racetrack Conference...
# 9899       Tables  Chromcraft Bull-Nose Wood Oval Conference Tabl...
# 9937       Tables       Hon 61000 Series Interactive Training Tables
# 9955       Tables  Bush Andora Conference Table, Maple/Graphite G...
# 9980       Tables                         KI Adjustable-Height Table
#
#           Sales  Quantity  Discount    Profit
# 3      957.5775         5      0.45 -383.0310
# 10    1706.1840         9      0.20   85.3092
# 24    1044.6300         3      0.00  240.2649
# 117    787.5300         3      0.00  165.3813
# 125    617.7000         6      0.50 -407.6820
# ...         ...       ...       ...       ...
# 9857  3393.6800         8      0.00  610.8624
# 9899   330.5880         1      0.40 -143.2548
# 9937    71.0880         2      0.20   -1.7772
# 9955   273.5680         2      0.20   10.2588
# 9980    85.9800         1      0.00   22.3548
#
# [319 rows x 21 columns]

# %%
# Show the cities with orders including "Tables"
df_store.query("`Sub-Category` == 'Tables'")[['City', 'Sub-Category']]
# Out:
#                  City Sub-Category
# 3     Fort Lauderdale       Tables
# 10        Los Angeles       Tables
# 24               Orem       Tables
# 117           Seattle       Tables
# 125       Bloomington       Tables
# ...               ...          ...
# 9857          Seattle       Tables
# 9899      Springfield       Tables
# 9937      Los Angeles       Tables
# 9955      Los Angeles       Tables
# 9980        Lafayette       Tables
#
# [319 rows x 2 columns]

# %%
df_store[df_store['Sub-Category'] == 'Tables'][['City']]
# Out:
#                  City
# 3     Fort Lauderdale
# 10        Los Angeles
# 24               Orem
# 117           Seattle
# 125       Bloomington
# ...               ...
# 9857          Seattle
# 9899      Springfield
# 9937      Los Angeles
# 9955      Los Angeles
# 9980        Lafayette
#
# [319 rows x 1 columns]

# %%
# Create a variable (type Series) of cities with orders including Tables. Show 5 random elements.
cities_series = df_store.loc[df_store['Sub-Category'] == 'Tables', 'City'].sample(n=5, random_state=1)
cities_series
# Out:
# 3614      San Antonio
# 3257         Franklin
# 2277        Southaven
# 3914          Phoenix
# 3979    New York City
# Name: City, dtype: object

# %%
# Create a variable (type DataFrame) of cities with orders including Chairs. Show the 3 last elements.
cities_df = df_store[df_store['Sub-Category'] == 'Chairs'][['City', 'Sub-Category']].tail(3)
cities_df
# Out:
#                City Sub-Category
# 9912  Santa Barbara       Chairs
# 9919          Bryan       Chairs
# 9947   Indianapolis       Chairs

# %%
# Show all the order lines including Phones to 'Los Angeles'
df_store[(df_store['Sub-Category'] == 'Phones') & (df_store['City'] == 'Los Angeles')]
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 7          8  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# 11        12  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# 90        91  CA-2016-109806 2016-09-17 2016-09-22  Standard Class
# 218      219  CA-2016-130162 2016-10-28 2016-11-01  Standard Class
# 477      478  CA-2016-103891 2016-07-12 2016-07-19  Standard Class
# ...      ...             ...        ...        ...             ...
# 9234    9235  CA-2016-126732 2016-09-02 2016-09-06  Standard Class
# 9454    9455  CA-2015-129546 2015-09-28 2015-10-05  Standard Class
# 9764    9765  CA-2014-123855 2014-06-18 2014-06-23  Standard Class
# 9973    9974  US-2016-103674 2016-12-06 2016-12-10  Standard Class
# 9976    9977  US-2016-103674 2016-12-06 2016-12-10  Standard Class
#
#      Customer ID     Customer Name      Segment        Country         City  \
# 7       BH-11710   Brosina Hoffman     Consumer  United States  Los Angeles
# 11      BH-11710   Brosina Hoffman     Consumer  United States  Los Angeles
# 90      JS-15685          Jim Sink    Corporate  United States  Los Angeles
# 218     JH-15910   Jonathan Howell     Consumer  United States  Los Angeles
# 477     KH-16690  Kristen Hastings    Corporate  United States  Los Angeles
# ...          ...               ...          ...            ...          ...
# 9234    LR-16915      Lena Radford     Consumer  United States  Los Angeles
# 9454    RP-19855          Roy Phan    Corporate  United States  Los Angeles
# 9764    MC-18100     Mick Crebagga     Consumer  United States  Los Angeles
# 9973    AP-10720        Anne Pryor  Home Office  United States  Los Angeles
# 9976    AP-10720        Anne Pryor  Home Office  United States  Los Angeles
#
#       ... Postal Code  Region       Product ID    Category Sub-Category  \
# 7     ...       90032    West  TEC-PH-10002275  Technology       Phones
# 11    ...       90032    West  TEC-PH-10002033  Technology       Phones
# 90    ...       90036    West  TEC-PH-10004093  Technology       Phones
# 218   ...       90032    West  TEC-PH-10002563  Technology       Phones
# 477   ...       90008    West  TEC-PH-10000149  Technology       Phones
# ...   ...         ...     ...              ...         ...          ...
# 9234  ...       90036    West  TEC-PH-10001530  Technology       Phones
# 9454  ...       90032    West  TEC-PH-10003555  Technology       Phones
# 9764  ...       90036    West  TEC-PH-10000215  Technology       Phones
# 9973  ...       90032    West  TEC-PH-10004080  Technology       Phones
# 9976  ...       90032    West  TEC-PH-10002496  Technology       Phones
#
#                                            Product Name     Sales  Quantity  \
# 7                        Mitel 5320 IP Phone VoIP phone   907.152         6
# 11        Konftel 250 Conference phone - Charcoal black   911.424         4
# 90                                   Panasonic Kx-TS550    73.584         2
# 218                                    Adtran 1202752G1   302.376         3
# 477                  Cisco SPA525G2 IP Phone - Wireless    95.760         6
# ...                                                 ...       ...       ...
# 9234            Cisco Unified IP Phone 7945G VoIP phone  1091.168         4
# 9454         Motorola HK250 Universal Bluetooth Headset    36.784         2
# 9764  Plantronics Cordless Phone Headset with In-lin...   139.800         5
# 9973                           Avaya 5410 Digital phone   271.960         5
# 9976                                       Cisco SPA301   249.584         2
#
#       Discount   Profit
# 7          0.2  90.7152
# 11         0.2  68.3568
# 90         0.2   8.2782
# 218        0.2  22.6782
# 477        0.2   7.1820
# ...        ...      ...
# 9234       0.2  68.1980
# 9454       0.2  -8.2764
# 9764       0.2  12.2325
# 9973       0.2  27.1960
# 9976       0.2  31.1980
#
# [74 rows x 21 columns]

# %%
# Show 10 random order lines with Phones or Tables
df_store[df_store['Sub-Category'].isin(['Phones', 'Tables'])]
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 3          4  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 7          8  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# 10        11  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# 11        12  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# 19        20  CA-2014-143336 2014-08-27 2014-09-01    Second Class
# ...      ...             ...        ...        ...             ...
# 9976    9977  US-2016-103674 2016-12-06 2016-12-10  Standard Class
# 9980    9981  US-2015-151435 2015-09-06 2015-09-09    Second Class
# 9983    9984  US-2016-157728 2016-09-22 2016-09-28  Standard Class
# 9988    9989  CA-2017-163629 2017-11-17 2017-11-21  Standard Class
# 9991    9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
#
#      Customer ID       Customer Name      Segment        Country  \
# 3       SO-20335      Sean O'Donnell     Consumer  United States
# 7       BH-11710     Brosina Hoffman     Consumer  United States
# 10      BH-11710     Brosina Hoffman     Consumer  United States
# 11      BH-11710     Brosina Hoffman     Consumer  United States
# 19      ZD-21925  Zuschuss Donatelli     Consumer  United States
# ...          ...                 ...          ...            ...
# 9976    AP-10720          Anne Pryor  Home Office  United States
# 9980    SW-20455         Shaun Weien     Consumer  United States
# 9983    RC-19960          Ryan Crowe     Consumer  United States
# 9988    RA-19885        Ruben Ausman    Corporate  United States
# 9991    DB-13060         Dave Brooks     Consumer  United States
#
#                  City  ... Postal Code   Region       Product ID    Category  \
# 3     Fort Lauderdale  ...       33311    South  FUR-TA-10000577   Furniture
# 7         Los Angeles  ...       90032     West  TEC-PH-10002275  Technology
# 10        Los Angeles  ...       90032     West  FUR-TA-10001539   Furniture
# 11        Los Angeles  ...       90032     West  TEC-PH-10002033  Technology
# 19      San Francisco  ...       94109     West  TEC-PH-10001949  Technology
# ...               ...  ...         ...      ...              ...         ...
# 9976      Los Angeles  ...       90032     West  TEC-PH-10002496  Technology
# 9980        Lafayette  ...       70506    South  FUR-TA-10001039   Furniture
# 9983     Grand Rapids  ...       49505  Central  TEC-PH-10001305  Technology
# 9988           Athens  ...       30605    South  TEC-PH-10004006  Technology
# 9991       Costa Mesa  ...       92627     West  TEC-PH-10003645  Technology
#
#      Sub-Category                                   Product Name      Sales  \
# 3          Tables  Bretford CR4500 Series Slim Rectangular Table   957.5775
# 7          Phones                 Mitel 5320 IP Phone VoIP phone   907.1520
# 10         Tables       Chromcraft Rectangular Conference Tables  1706.1840
# 11         Phones  Konftel 250 Conference phone - Charcoal black   911.4240
# 19         Phones                        Cisco SPA 501G IP Phone   213.4800
# ...           ...                                            ...        ...
# 9976       Phones                                   Cisco SPA301   249.5840
# 9980       Tables                     KI Adjustable-Height Table    85.9800
# 9983       Phones               Panasonic KX TS208W Corded phone    97.9800
# 9988       Phones                Panasonic KX - TS880B Telephone   206.1000
# 9991       Phones                          Aastra 57i VoIP phone   258.5760
#
#       Quantity  Discount    Profit
# 3            5      0.45 -383.0310
# 7            6      0.20   90.7152
# 10           9      0.20   85.3092
# 11           4      0.20   68.3568
# 19           3      0.20   16.0110
# ...        ...       ...       ...
# 9976         2      0.20   31.1980
# 9980         1      0.00   22.3548
# 9983         2      0.00   27.4344
# 9988         5      0.00   55.6470
# 9991         2      0.20   19.3932
#
# [1208 rows x 21 columns]

# %%
# Select the second row of the dataframe
df_store[df_store['Sub-Category'].isin(['Phones', 'Tables'])].iloc[[1]]
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 7       8  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
#
#      Customer Name   Segment        Country         City  ... Postal Code  \
# 7  Brosina Hoffman  Consumer  United States  Los Angeles  ...       90032
#
#    Region       Product ID    Category Sub-Category  \
# 7    West  TEC-PH-10002275  Technology       Phones
#
#                      Product Name    Sales  Quantity  Discount   Profit
# 7  Mitel 5320 IP Phone VoIP phone  907.152         6       0.2  90.7152
#
# [1 rows x 21 columns]

# %%
# Select the third, seventh and 24 row of the dataset
df_store.iloc[[3, 7, 24]]
# Out:
#     Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 3        4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 7        8  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 24      25  CA-2015-106320 2015-09-25 2015-09-30  Standard Class    EB-13870
#
#       Customer Name   Segment        Country             City  ...  \
# 3    Sean O'Donnell  Consumer  United States  Fort Lauderdale  ...
# 7   Brosina Hoffman  Consumer  United States      Los Angeles  ...
# 24      Emily Burns  Consumer  United States             Orem  ...
#
#    Postal Code  Region       Product ID    Category Sub-Category  \
# 3        33311   South  FUR-TA-10000577   Furniture       Tables
# 7        90032    West  TEC-PH-10002275  Technology       Phones
# 24       84057    West  FUR-TA-10000577   Furniture       Tables
#
#                                      Product Name      Sales  Quantity  \
# 3   Bretford CR4500 Series Slim Rectangular Table   957.5775         5
# 7                  Mitel 5320 IP Phone VoIP phone   907.1520         6
# 24  Bretford CR4500 Series Slim Rectangular Table  1044.6300         3
#
#     Discount    Profit
# 3       0.45 -383.0310
# 7       0.20   90.7152
# 24      0.00  240.2649
#
# [3 rows x 21 columns]

# %%
# create a dataframe (sales) with the client name, city, product name and quantity from West region
sales = df_store.query("Region == 'West'")[['Customer Name', 'City', 'Product Name', 'Quantity']]
sales
# Out:
#         Customer Name         City  \
# 2     Darrin Van Huff  Los Angeles
# 5     Brosina Hoffman  Los Angeles
# 6     Brosina Hoffman  Los Angeles
# 7     Brosina Hoffman  Los Angeles
# 8     Brosina Hoffman  Los Angeles
# ...               ...          ...
# 9986     Maris LaWare  Los Angeles
# 9990      Dave Brooks   Costa Mesa
# 9991      Dave Brooks   Costa Mesa
# 9992      Dave Brooks   Costa Mesa
# 9993     Chris Cortes  Westminster
#
#                                            Product Name  Quantity
# 2     Self-Adhesive Address Labels for Typewriters b...         2
# 5     Eldon Expressions Wood and Plastic Desk Access...         7
# 6                                            Newell 322         4
# 7                        Mitel 5320 IP Phone VoIP phone         6
# 8     DXL Angle-View Binders with Locking Rings by S...         3
# ...                                                 ...       ...
# 9986  Memorex Mini Travel Drive 64 GB USB 2.0 Flash ...         1
# 9990  Tenex B1-RE Series Chair Mats for Low Pile Car...         2
# 9991                              Aastra 57i VoIP phone         2
# 9992  It's Hot Message Books with Stickers, 2 3/4" x 5"         4
# 9993  Acco 7-Outlet Masterpiece Power Center, Wihtou...         2
#
# [3203 rows x 4 columns]

# %%
# Select the second row from the previous DataFrame (sales) using position
sales.iloc[[1]]
# Out:
#      Customer Name         City  \
# 5  Brosina Hoffman  Los Angeles
#
#                                         Product Name  Quantity
# 5  Eldon Expressions Wood and Plastic Desk Access...         7

# %%
# Think about what's the best column in the spreadsheet to use it as an index and load the file again in a new DataFrame
df_store2 = pd.read_excel('../../data/Sample_Superstore.xls', index_col=1)
df_store2.head()
# Out:
#                 Row ID Order Date  Ship Date       Ship Mode Customer ID  \
# Order ID
# CA-2016-152156       1 2016-11-08 2016-11-11    Second Class    CG-12520
# CA-2016-152156       2 2016-11-08 2016-11-11    Second Class    CG-12520
# CA-2016-138688       3 2016-06-12 2016-06-16    Second Class    DV-13045
# US-2015-108966       4 2015-10-11 2015-10-18  Standard Class    SO-20335
# US-2015-108966       5 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#                   Customer Name    Segment        Country             City  \
# Order ID
# CA-2016-152156      Claire Gute   Consumer  United States        Henderson
# CA-2016-152156      Claire Gute   Consumer  United States        Henderson
# CA-2016-138688  Darrin Van Huff  Corporate  United States      Los Angeles
# US-2015-108966   Sean O'Donnell   Consumer  United States  Fort Lauderdale
# US-2015-108966   Sean O'Donnell   Consumer  United States  Fort Lauderdale
#
#                      State  Postal Code Region       Product ID  \
# Order ID
# CA-2016-152156    Kentucky        42420  South  FUR-BO-10001798
# CA-2016-152156    Kentucky        42420  South  FUR-CH-10000454
# CA-2016-138688  California        90036   West  OFF-LA-10000240
# US-2015-108966     Florida        33311  South  FUR-TA-10000577
# US-2015-108966     Florida        33311  South  OFF-ST-10000760
#
#                        Category Sub-Category  \
# Order ID
# CA-2016-152156        Furniture    Bookcases
# CA-2016-152156        Furniture       Chairs
# CA-2016-138688  Office Supplies       Labels
# US-2015-108966        Furniture       Tables
# US-2015-108966  Office Supplies      Storage
#
#                                                      Product Name     Sales  \
# Order ID
# CA-2016-152156                  Bush Somerset Collection Bookcase  261.9600
# CA-2016-152156  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400
# CA-2016-138688  Self-Adhesive Address Labels for Typewriters b...   14.6200
# US-2015-108966      Bretford CR4500 Series Slim Rectangular Table  957.5775
# US-2015-108966                     Eldon Fold 'N Roll Cart System   22.3680
#
#                 Quantity  Discount    Profit
# Order ID
# CA-2016-152156         2      0.00   41.9136
# CA-2016-152156         3      0.00  219.5820
# CA-2016-138688         2      0.00    6.8714
# US-2015-108966         5      0.45 -383.0310
# US-2015-108966         2      0.20    2.5164

# %%
# Select the fifth row
df_store2.iloc[[4]]
# Out:
#                 Row ID Order Date  Ship Date       Ship Mode Customer ID  \
# Order ID
# US-2015-108966       5 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#                  Customer Name   Segment        Country             City  \
# Order ID
# US-2015-108966  Sean O'Donnell  Consumer  United States  Fort Lauderdale
#
#                   State  Postal Code Region       Product ID         Category  \
# Order ID
# US-2015-108966  Florida        33311  South  OFF-ST-10000760  Office Supplies
#
#                Sub-Category                    Product Name   Sales  Quantity  \
# Order ID
# US-2015-108966      Storage  Eldon Fold 'N Roll Cart System  22.368         2
#
#                 Discount  Profit
# Order ID
# US-2015-108966       0.2  2.5164

# %%
# Select rows from the third to the seventh one
df_store2.iloc[1:7]
# Out:
#                 Row ID Order Date  Ship Date       Ship Mode Customer ID  \
# Order ID
# CA-2016-152156       2 2016-11-08 2016-11-11    Second Class    CG-12520
# CA-2016-138688       3 2016-06-12 2016-06-16    Second Class    DV-13045
# US-2015-108966       4 2015-10-11 2015-10-18  Standard Class    SO-20335
# US-2015-108966       5 2015-10-11 2015-10-18  Standard Class    SO-20335
# CA-2014-115812       6 2014-06-09 2014-06-14  Standard Class    BH-11710
# CA-2014-115812       7 2014-06-09 2014-06-14  Standard Class    BH-11710
#
#                   Customer Name    Segment        Country             City  \
# Order ID
# CA-2016-152156      Claire Gute   Consumer  United States        Henderson
# CA-2016-138688  Darrin Van Huff  Corporate  United States      Los Angeles
# US-2015-108966   Sean O'Donnell   Consumer  United States  Fort Lauderdale
# US-2015-108966   Sean O'Donnell   Consumer  United States  Fort Lauderdale
# CA-2014-115812  Brosina Hoffman   Consumer  United States      Los Angeles
# CA-2014-115812  Brosina Hoffman   Consumer  United States      Los Angeles
#
#                      State  Postal Code Region       Product ID  \
# Order ID
# CA-2016-152156    Kentucky        42420  South  FUR-CH-10000454
# CA-2016-138688  California        90036   West  OFF-LA-10000240
# US-2015-108966     Florida        33311  South  FUR-TA-10000577
# US-2015-108966     Florida        33311  South  OFF-ST-10000760
# CA-2014-115812  California        90032   West  FUR-FU-10001487
# CA-2014-115812  California        90032   West  OFF-AR-10002833
#
#                        Category Sub-Category  \
# Order ID
# CA-2016-152156        Furniture       Chairs
# CA-2016-138688  Office Supplies       Labels
# US-2015-108966        Furniture       Tables
# US-2015-108966  Office Supplies      Storage
# CA-2014-115812        Furniture  Furnishings
# CA-2014-115812  Office Supplies          Art
#
#                                                      Product Name     Sales  \
# Order ID
# CA-2016-152156  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400
# CA-2016-138688  Self-Adhesive Address Labels for Typewriters b...   14.6200
# US-2015-108966      Bretford CR4500 Series Slim Rectangular Table  957.5775
# US-2015-108966                     Eldon Fold 'N Roll Cart System   22.3680
# CA-2014-115812  Eldon Expressions Wood and Plastic Desk Access...   48.8600
# CA-2014-115812                                         Newell 322    7.2800
#
#                 Quantity  Discount    Profit
# Order ID
# CA-2016-152156         3      0.00  219.5820
# CA-2016-138688         2      0.00    6.8714
# US-2015-108966         5      0.45 -383.0310
# US-2015-108966         2      0.20    2.5164
# CA-2014-115812         7      0.00   14.1694
# CA-2014-115812         4      0.00    1.9656

# %%
# Select penultimate row
df_store2.iloc[[-2]]
# Out:
#                 Row ID Order Date  Ship Date       Ship Mode Customer ID  \
# Order ID
# CA-2017-121258    9993 2017-02-26 2017-03-03  Standard Class    DB-13060
#
#                Customer Name   Segment        Country        City       State  \
# Order ID
# CA-2017-121258   Dave Brooks  Consumer  United States  Costa Mesa  California
#
#                 Postal Code Region       Product ID         Category  \
# Order ID
# CA-2017-121258        92627   West  OFF-PA-10004041  Office Supplies
#
#                Sub-Category  \
# Order ID
# CA-2017-121258        Paper
#
#                                                      Product Name  Sales  \
# Order ID
# CA-2017-121258  It's Hot Message Books with Stickers, 2 3/4" x 5"   29.6
#
#                 Quantity  Discount  Profit
# Order ID
# CA-2017-121258         4       0.0   13.32

# %%
# Select, given the last 5 rows, all but the last one.
df_store2.iloc[-5:-1]
# Out:
#                 Row ID Order Date  Ship Date       Ship Mode Customer ID  \
# Order ID
# CA-2014-110422    9990 2014-01-21 2014-01-23    Second Class    TB-21400
# CA-2017-121258    9991 2017-02-26 2017-03-03  Standard Class    DB-13060
# CA-2017-121258    9992 2017-02-26 2017-03-03  Standard Class    DB-13060
# CA-2017-121258    9993 2017-02-26 2017-03-03  Standard Class    DB-13060
#
#                    Customer Name   Segment        Country        City  \
# Order ID
# CA-2014-110422  Tom Boeckenhauer  Consumer  United States       Miami
# CA-2017-121258       Dave Brooks  Consumer  United States  Costa Mesa
# CA-2017-121258       Dave Brooks  Consumer  United States  Costa Mesa
# CA-2017-121258       Dave Brooks  Consumer  United States  Costa Mesa
#
#                      State  Postal Code Region       Product ID  \
# Order ID
# CA-2014-110422     Florida        33180  South  FUR-FU-10001889
# CA-2017-121258  California        92627   West  FUR-FU-10000747
# CA-2017-121258  California        92627   West  TEC-PH-10003645
# CA-2017-121258  California        92627   West  OFF-PA-10004041
#
#                        Category Sub-Category  \
# Order ID
# CA-2014-110422        Furniture  Furnishings
# CA-2017-121258        Furniture  Furnishings
# CA-2017-121258       Technology       Phones
# CA-2017-121258  Office Supplies        Paper
#
#                                                      Product Name    Sales  \
# Order ID
# CA-2014-110422                             Ultra Door Pull Handle   25.248
# CA-2017-121258  Tenex B1-RE Series Chair Mats for Low Pile Car...   91.960
# CA-2017-121258                              Aastra 57i VoIP phone  258.576
# CA-2017-121258  It's Hot Message Books with Stickers, 2 3/4" x 5"   29.600
#
#                 Quantity  Discount   Profit
# Order ID
# CA-2014-110422         3       0.2   4.1028
# CA-2017-121258         2       0.0  15.6332
# CA-2017-121258         2       0.2  19.3932
# CA-2017-121258         4       0.0  13.3200

# %%
# Depending on what we need, we can use loc or iloc
# loc <- work with index/labels
# iloc <- work with positions

# %%
# Write to XLS all the sales in the State of California
california_sales = sales.query("City == 'California'")

# %%
# Give a name to the sheet ('California') 
california_sales.to_excel('../../data/california_sales.xlsx', sheet_name='California', index=False)

# %%
californian_df = pd.read_excel('../../data/california_sales.xlsx', sheet_name='California')
californian_df
# Out:
# Empty DataFrame
# Columns: [Customer Name, City, Product Name, Quantity]
# Index: []

# %%
# Save the sales rows in the west or south. 
# Save the product name, identifier, quantity and discount. 
# Save the result in a file sales_WS.xlsx
# Try to do it all in a single row
df_store2.query("Region in ['West', 'South']")[['Product Name', 'Product ID', 'Quantity', 'Discount']].to_excel('../../data/sales_WS.xlsx', index=False)
